# %% [markdown]
# Read csv files
# Link to documentation here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %% [markdown]
#  Read text files
#  Link to documentation here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_table.html

# %% [markdown]
# Read xlsx files
# Link to documentation here: https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %%
#read the excel file and create a dataframe for both sheets

# %%
#read the text file and create a dataframe

# %%
#read the csv file and create a dataframe

# %%
#for each dataset perform the following

# %%
#number of rows

# %%
#number of columns

# %%
#unique column names

# %%
#data types

# %%
#check the first 2 rows of the dataframe
